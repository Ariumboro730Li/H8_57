# %%
import numpy as np
import pandas as pd

data = "fulltimeSD.csv"
source = pd.read_csv(data)

source.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   position     414 non-null    object
#  1   company      414 non-null    object
#  2   description  414 non-null    object
#  3   numreview    325 non-null    object
#  4   location     414 non-null    object
# dtypes: object(5)
# memory usage: 16.3+ KB

# %%
source.head()
# Out:
#                                             position  \
# 0  Experimental Design and Statistical Analysis S...
# 1    Computational Biologist/Bioinformatics Position
# 2   Machine Learning - Software Engineer / Scientist
# 3                   Business Intelligence Specialist
# 4                            Translational Scientist
#
#                                          company  \
# 0                       SDSU Research Foundation
# 1  La Jolla Institute for Allergy and Immunology
# 2                              Brain Corporation
# 3              Facility Management Planners, Inc
# 4                                          Viome
#
#                                          description   numreview  \
# 0  <span id="job_summary" class="summary"><div><h...  20 reviews
# 1  <span id="job_summary" class="summary">A posit...  10 reviews
# 2  <span id="job_summary" class="summary"><div><p...         NaN
# 3  <span id="job_summary" class="summary"><p>At F...         NaN
# ...

# %%
newIndex = source.set_index("company", inplace=False)

# %%
newIndex.loc['Viome']
# Out:
# position                                 Translational Scientist
# description    <span id="job_summary" class="summary">Viome i...
# numreview                                                    NaN
# location                                           San Diego, CA
# Name: Viome, dtype: object

# %%
viome = newIndex.loc[['Viome']]

# %%
viome
# Out:
#                         position  \
# company
# Viome    Translational Scientist
#
#                                                description numreview  \
# company
# Viome    <span id="job_summary" class="summary">Viome i...       NaN
#
#               location
# company
# Viome    San Diego, CA

# %%
viome.transpose()
# Out:
# company                                                  Viome
# position                               Translational Scientist
# description  <span id="job_summary" class="summary">Viome i...
# numreview                                                  NaN
# location                                         San Diego, CA

# %%
source['company'].value_counts()
# Out:
# Cymer                            32
# Illumina                         25
# Celgene Corporation              15
# ASML                             12
# UC San Diego                     11
#                                  ..
# Systems Planning and Analysis     1
# Syndicus Inc                      1
# Streamlyne                        1
# RTI International                 1
# Arcturus Therapeutics             1
# Name: company, Length: 176, dtype: int64

# %%
Cymer = newIndex.loc[['Cymer']]
Cymer
# Out:
#                                                   position  \
# company
# Cymer    Sr Automation and Machine Damage Control Engineer
# Cymer                   Light Source Research Data Analyst
# Cymer                                      Sr Data Analyst
# Cymer                          Discharge Chamber Scientist
# Cymer                    Staff Discharge Chamber Scientist
# Cymer                      Sr Mechanical Engineer, Tooling
# Cymer                           Mechanical Design Engineer
# Cymer                                Lead Tooling Engineer
# Cymer                      Manager, Mechanical Engineering
# Cymer                                 Sr Software Engineer
# Cymer               Staff Automation and Control Architect
# Cymer                    Staff Software Engineer/Architect
# Cymer                          Sr Opto-Mechanical Engineer
# Cymer                               Sr Mechanical Engineer
# Cymer        Principal Systems Design Functional Architect
# ...

# %%
Cymer.transpose()
# Out:
# company                                                  Cymer  \
# position     Sr Automation and Machine Damage Control Engineer
# description  <span id="job_summary" class="summary"><div><d...
# numreview                                           52 reviews
# location                                         San Diego, CA
#
# company                                                  Cymer  \
# position                    Light Source Research Data Analyst
# description  <span id="job_summary" class="summary"><div><d...
# numreview                                           52 reviews
# location                                         San Diego, CA
#
# company                                                  Cymer  \
# position                                       Sr Data Analyst
# description  <span id="job_summary" class="summary"><div><d...
# numreview                                           52 reviews
# location                                         San Diego, CA
#
# ...
