# %%
import numpy as np
import pandas as pd

datasource = "fulltimeNY.csv"

df = pd.read_csv(datasource)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   position     986 non-null    object
#  1   company      986 non-null    object
#  2   description  986 non-null    object
#  3   numreview    755 non-null    object
#  4   location     986 non-null    object
# dtypes: object(5)
# memory usage: 38.6+ KB

# %%
#print(df['numreview'].isnull().value_counts())
#print("-------")
print(df['numreview'].value_counts())

dfr = df['numreview'] == "1, reviews"
df['numreview'][dfr].value_counts()
# Out:
# 705 reviews       76
# 7 reviews         26
# 2 reviews         26
# 8 reviews         26
# 20,319 reviews    24
#                   ..
# 1,341 reviews      1
# 32 reviews         1
# 1,189 reviews      1
# 307 reviews        1
# 82 reviews         1
# Name: numreview, Length: 190, dtype: int64
# Series([], Name: numreview, dtype: int64)

# %%
filternull = df["numreview"].isnull()
df[filternull]

dfr = df['company'] == "JP Morgan Chase"
df['company'][dfr].value_counts()
# Out:
# JP Morgan Chase    24
# Name: company, dtype: int64

# %%
df['numreview'].fillna("1999 reviews", inplace=True)

# %%
pd.set_option('display.max.rows',None)

dfr = df['numreview'] == "1999 reviews"
df['numreview'].value_counts()
# Out:
# 1999 reviews      231
# 705 reviews        76
# 7 reviews          26
# 2 reviews          26
# 8 reviews          26
# 20,319 reviews     24
# 5 reviews          19
# 4 reviews          19
# 4,491 reviews      17
# 3 reviews          17
# 749 reviews        15
# 33 reviews         14
# 25,883 reviews     13
# 366 reviews        11
# 456 reviews        10
# 1,148 reviews      10
# 385 reviews        10
# 1,029 reviews      10
# 12 reviews          9
# 6 reviews           9
# 151 reviews         9
# 40 reviews          8
# 1,677 reviews       8
# 9 reviews           8
# 2,473 reviews       8
# 15 reviews          7
# 703 reviews         7
# 6,318 reviews       7
# 605 reviews         7
# 699 reviews         6
# 143 reviews         6
# 30 reviews          6
# 92 reviews          6
# 19 reviews          6
# 13 reviews          6
# 21,942 reviews      6
# 108 reviews         6
# 10 reviews          6
# 70 reviews          5
# 586 reviews         4
# 2,694 reviews       4
# ...

# %%
df.describe()
df.head(100)
# Out:
#                                              position  \
# 0   Data Scientist—Research (Ref # EXEC/RD_DAT_NYC...
# 1                   Data Scientist/Pre Sales Engineer
# 2                     Data Analyst/Research Scientist
# 3                                      Data Scientist
# 4                                      Data Scientist
# 5                       Data Analyst / Data Scientist
# 6                                Staff Data Scientist
# 7                       Clinical Data Assistant - IPC
# 8                           Data Analytics Specialist
# 9              Data Scientist, Supply Chain Analytics
# 10                          Data Scientist, Analytics
# 11  Statistical Analyst/Data Scientist (Machine Le...
# 12                  Data Visualization Data Scientist
# 13                                     Data Scientist
# 14                 Data Scientist (Data Science Team)
# 15                                     Data Scientist
# ...
